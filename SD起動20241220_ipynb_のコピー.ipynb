# %%
# !pip install backend
# !pip install psd-tools

# !pip uninstall wandb --yes
# !pip install wandb==0.15.12

# !pip install pytorch_lightning==1.9.4
# !pip install pydantic==1.10.12
# !pip install insightface
# !pip install backend

# %%
# %cd /content/drive/MyDrive/stable-diffusion-webui
# !python launch.py --share --enable-insecure-extension-access --disable-safe-unpickle --device-id=0
# Out:
# /content/drive/MyDrive/stable-diffusion-webui
# Python 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# Version: v1.10.1
# Commit hash: 82a973c04367123ae98bd9abdf80d9eda9b910e2
# Installing clip
# Installing open_clip
# Installing requirements
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.3/901.3 kB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 55.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 27.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 84.1 kB/s eta 0:00:00
# ...
# sd-dynamic-prompts installer: running /usr/bin/python3 -m pip install 'dynamicprompts[attentiongrabber,magicprompt]~=0.31.0'
# Installing sd-webui-controlnet requirement: fvcore
# Installing sd-webui-controlnet requirement: svglib
# ...

# %% [markdown]
# ----------------------------

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui /content/drive/MyDrive/stable-diffusion-webui

#VAEのインストール
# %cd /content/drive/MyDrive/stable-diffusion-webui/models/VAE
# !wget -nc https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt --content-disposition
# !wget -nc https://huggingface.co/stabilityai/sdxl-vae/blob/main/sdxl_vae.safetensors --content-disposition

#拡張機能のインストール
# %cd /content/drive/MyDrive/stable-diffusion-webui/extensions
# !git clone https://github.com/Bing-su/adetailer
# !git clone https://github.com/zixaphir/Stable-Diffusion-Webui-Civitai-Helper
# !git clone https://github.com/adieyal/sd-dynamic-prompts
# !git clone https://github.com/Mikubill/sd-webui-controlnet
# !git clone https://github.com/Physton/sd-webui-prompt-all-in-one
# !git clone https://github.com/AI-Creators-Society/stable-diffusion-webui-localization-ja_JP
# !git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser
# !git clone https://github.com/hako-mikan/sd-webui-negpip
# !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111
# !git clone https://github.com/sugarkwork/mozaikukun
# !git clone https://github.com/picobyte/stable-diffusion-webui-wd14-tagger.git
# Out:
# /content/drive/MyDrive/stable-diffusion-webui/models/VAE
# --2024-12-19 09:36:13--  https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt
# Resolving huggingface.co (huggingface.co)... 3.169.137.119, 3.169.137.5, 3.169.137.19, ...
# Connecting to huggingface.co (huggingface.co)|3.169.137.119|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# --2024-12-19 09:36:13--  https://huggingface.co/stabilityai/sdxl-vae/blob/main/sdxl_vae.safetensors
# Resolving huggingface.co (huggingface.co)... 3.169.137.119, 3.169.137.19, 3.169.137.5, ...
# Connecting to huggingface.co (huggingface.co)|3.169.137.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# /content/drive/MyDrive/stable-diffusion-webui/extensions
# fatal: destination path 'adetailer' already exists and is not an empty directory.
# fatal: destination path 'Stable-Diffusion-Webui-Civitai-Helper' already exists and is not an empty directory.
# ...

# %%
#AUTOMATIC1111アップデート（アップデートが必要な時のみ実行）
# %cd /content/drive/MyDrive/stable-diffusion-webui
# !git checkout master
# !git pull
